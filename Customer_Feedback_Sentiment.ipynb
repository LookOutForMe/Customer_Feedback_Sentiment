# %% [markdown]
# ##Importing Necessary Libraries

# %%
import pandas as pd
import sqlite3
import numpy as np

# %% [markdown]
# ##Mounting Google Drive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Path Of The Dataset

# %%
path = '/content/drive/MyDrive/Customer_Sentiment/test.ft.txt.bz2'
print(path)
# Out:
# /content/drive/MyDrive/Customer_Sentiment/test.ft.txt.bz2

# %% [markdown]
# ##Extract Labeled Text Data from a Compressed .bz2 File into a DataFrame

# %%
import bz2
def extractData(filename):
    data = []
    with bz2.open(filename, 'rt', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split(' ', 1)
            if len(parts) == 2:
                label, text = parts
                data.append((label, text))

    data = pd.DataFrame(data, columns=['label', 'text'])
    data['label'] = data['label'].str.extract(r'(\d+)').astype(int)
    return data

# %%
data = extractData(path)
data.head(10)
# Out:
#    label                                               text
# 0      2  Great CD: My lovely Pat has one of the GREAT v...
# 1      2  One of the best game music soundtracks - for a...
# 2      1  Batteries died within a year ...: I bought thi...
# 3      2  works fine, but Maha Energy is better: Check o...
# 4      2  Great for the non-audiophile: Reviewed quite a...
# 5      1  DVD Player crapped out after one year: I also ...
# 6      1  Incorrect Disc: I love the style of this, but ...
# 7      1  DVD menu select problems: I cannot scroll thro...
# 8      2  Unique Weird Orientalia from the 1930's: Exoti...
# 9      1  Not an "ultimate guide": Firstly,I enjoyed the...

# %% [markdown]
# ##Install and Load VADER Sentiment Lexicon for Text Sentiment Analysis using NLTK

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ##Generate Sentiment Scores and Labels from Text using NLTK VADER Analyzer

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
def get_sentiment(text):
    score = analyzer.polarity_scores(str(text))['compound']
    return score
data['sentiment_score'] = data['text'].apply(get_sentiment)
data['sentiment_label'] = data['sentiment_score'].apply(
    lambda x: 'Positive' if x > 0.05 else ('Negative' if x < -0.05 else 'Neutral')
)

# %%
data.head(25)
# Out:
#     label                                               text  sentiment_score  \
# 0       2  Great CD: My lovely Pat has one of the GREAT v...           0.9569
# 1       2  One of the best game music soundtracks - for a...           0.8770
# 2       1  Batteries died within a year ...: I bought thi...           0.7297
# 3       2  works fine, but Maha Energy is better: Check o...           0.7845
# 4       2  Great for the non-audiophile: Reviewed quite a...           0.8388
# 5       1  DVD Player crapped out after one year: I also ...          -0.3506
# 6       1  Incorrect Disc: I love the style of this, but ...          -0.0638
# 7       1  DVD menu select problems: I cannot scroll thro...           0.2329
# 8       2  Unique Weird Orientalia from the 1930's: Exoti...           0.1280
# 9       1  Not an "ultimate guide": Firstly,I enjoyed the...           0.9633
# 10      2  Great book for travelling Europe: I currently ...           0.8555
# 11      1  Not!: If you want to listen to El Duke , then ...           0.6800
# 12      1  A complete Bust: This game requires quicktime ...           0.1864
# 13      2  TRULY MADE A DIFFERENCE!: I have been using th...           0.9788
# 14      1  didn't run off of USB bus power: Was hoping th...          -0.4497
# 15      1  Don't buy!: First of all, the company took my ...          -0.1836
# 16      2  Simple, Durable, Fun game for all ages: This i...           0.9695
# 17      2  Review of Kelly Club for Toddlers: For the pri...           0.9235
# 18      2  SOY UN APASIONADO DEL BOX: Y ESTE LIBRO ESTÁ E...           0.0000
# 19      2  Some of the best fiddle playing I have heard i...           0.9657
# 20      1  Long and boring: I've read this book with much...          -0.5574
# 21      1  Dont like it: This product smells when you ope...           0.2755
# 22      2  one of the last in the series to collect !: Th...           0.7495
# 23      2  Sony Hi8 Camcorder with 2.5 LCD: I believe I w...           0.8588
# 24      1  Don't Take the Chance - Get the SE Branded Cab...           0.8369
#
#    sentiment_label
# 0         Positive
# 1         Positive
# 2         Positive
# 3         Positive
# 4         Positive
# 5         Negative
# 6         Negative
# 7         Positive
# 8         Positive
# 9         Positive
# 10        Positive
# 11        Positive
# 12        Positive
# 13        Positive
# 14        Negative
# 15        Negative
# 16        Positive
# 17        Positive
# 18         Neutral
# 19        Positive
# 20        Negative
# 21        Positive
# 22        Positive
# 23        Positive
# 24        Positive

# %% [markdown]
# ##Map Numerical Labels to Rating Categories using Conditional Logic

# %%
data['ratings'] = data['label'].apply(
    lambda x: '4 or 5' if str(x).strip() == '2' else ('1 or 2' if str(x).strip() == '1' else 'Unknown Rating')
)

# %%
data.head(25)
# Out:
#     label                                               text  sentiment_score  \
# 0       2  Great CD: My lovely Pat has one of the GREAT v...           0.9569
# 1       2  One of the best game music soundtracks - for a...           0.8770
# 2       1  Batteries died within a year ...: I bought thi...           0.7297
# 3       2  works fine, but Maha Energy is better: Check o...           0.7845
# 4       2  Great for the non-audiophile: Reviewed quite a...           0.8388
# 5       1  DVD Player crapped out after one year: I also ...          -0.3506
# 6       1  Incorrect Disc: I love the style of this, but ...          -0.0638
# 7       1  DVD menu select problems: I cannot scroll thro...           0.2329
# 8       2  Unique Weird Orientalia from the 1930's: Exoti...           0.1280
# 9       1  Not an "ultimate guide": Firstly,I enjoyed the...           0.9633
# 10      2  Great book for travelling Europe: I currently ...           0.8555
# 11      1  Not!: If you want to listen to El Duke , then ...           0.6800
# 12      1  A complete Bust: This game requires quicktime ...           0.1864
# 13      2  TRULY MADE A DIFFERENCE!: I have been using th...           0.9788
# 14      1  didn't run off of USB bus power: Was hoping th...          -0.4497
# 15      1  Don't buy!: First of all, the company took my ...          -0.1836
# 16      2  Simple, Durable, Fun game for all ages: This i...           0.9695
# 17      2  Review of Kelly Club for Toddlers: For the pri...           0.9235
# 18      2  SOY UN APASIONADO DEL BOX: Y ESTE LIBRO ESTÁ E...           0.0000
# 19      2  Some of the best fiddle playing I have heard i...           0.9657
# 20      1  Long and boring: I've read this book with much...          -0.5574
# 21      1  Dont like it: This product smells when you ope...           0.2755
# 22      2  one of the last in the series to collect !: Th...           0.7495
# 23      2  Sony Hi8 Camcorder with 2.5 LCD: I believe I w...           0.8588
# 24      1  Don't Take the Chance - Get the SE Branded Cab...           0.8369
#
#    sentiment_label ratings
# 0         Positive  4 or 5
# 1         Positive  4 or 5
# 2         Positive  1 or 2
# 3         Positive  4 or 5
# 4         Positive  4 or 5
# 5         Negative  1 or 2
# 6         Negative  1 or 2
# 7         Positive  1 or 2
# 8         Positive  4 or 5
# 9         Positive  1 or 2
# 10        Positive  4 or 5
# 11        Positive  1 or 2
# 12        Positive  1 or 2
# 13        Positive  4 or 5
# 14        Negative  1 or 2
# 15        Negative  1 or 2
# 16        Positive  4 or 5
# 17        Positive  4 or 5
# 18         Neutral  4 or 5
# 19        Positive  4 or 5
# 20        Negative  1 or 2
# 21        Positive  1 or 2
# 22        Positive  4 or 5
# 23        Positive  4 or 5
# 24        Positive  1 or 2

# %% [markdown]
# ##Visualize Sentiment Score Distribution and Generate Word Cloud for Negative Reviews

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#Sentiment score distributions
sns.histplot(data['sentiment_score'], bins=30)
plt.title('Sentiment Score Distribution')
plt.show()

# %%
#Word Cloud for Negative Reviews
negative_reviews = ' '.join(data[data['sentiment_label'] == 'Negative']['text'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(negative_reviews)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ##Establish Connection to SQLite Database for Customer Sentiment Analysis

# %%
conn = sqlite3.connect('/content/drive/MyDrive/Customer_Sentiment/customer_sentiment.db')

# %% [markdown]
# ##Create 'sentiment' Table in SQLite Database to Store Text, Sentiment Scores, and Ratings

# %%
conn.execute("""
CREATE TABLE IF NOT EXISTS sentiment (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    text TEXT,
    sentiment_score REAL,
    rating REAL);
""")

# %% [markdown]
# ##Sentiment Table Metadata

# %%
table_metadata = pd.read_sql_query("PRAGMA table_info(sentiment);", conn)
table_metadata
# Out:
#    cid             name     type  notnull dflt_value  pk
# 0    0               id  INTEGER        0       None   1
# 1    1             text     TEXT        0       None   0
# 2    2  sentiment_score     REAL        0       None   0
# 3    3           rating     REAL        0       None   0

# %%
data_check = pd.read_sql_query("select * from sentiment;", conn)
data_check
# Out:
# Empty DataFrame
# Columns: [id, text, sentiment_score, rating]
# Index: []

# %% [markdown]
# ##Insert Text, Sentiment Scores, and Ratings into the 'sentiment' Table in SQLite Database

# %%
for _, data in data.iterrows():
  conn.execute('''
  insert into sentiment(text,sentiment_score,rating)
  values(?,?,?)''', (data['text'],data['sentiment_score'],data['ratings']))

conn.commit
# Out:
# <function Connection.commit()>

# %%
data_check_1 = pd.read_sql_query("select * from sentiment", conn)
data_check_1
# Out:
#             id                                               text  \
# 0            1  Great CD: My lovely Pat has one of the GREAT v...
# 1            2  One of the best game music soundtracks - for a...
# 2            3  Batteries died within a year ...: I bought thi...
# 3            4  works fine, but Maha Energy is better: Check o...
# 4            5  Great for the non-audiophile: Reviewed quite a...
# ...        ...                                                ...
# 399995  399996  Unbelievable- In a Bad Way: We bought this Tho...
# 399996  399997  Almost Great, Until it Broke...: My son reciev...
# 399997  399998  Disappointed !!!: I bought this toy for my son...
# 399998  399999  Classic Jessica Mitford: This is a compilation...
# 399999  400000  Comedy Scene, and Not Heard: This DVD will be ...
#
#         sentiment_score  rating
# 0                0.9569  4 or 5
# 1                0.8770  4 or 5
# 2                0.7297  1 or 2
# 3                0.7845  4 or 5
# 4                0.8388  4 or 5
# ...                 ...     ...
# 399995           0.5932  1 or 2
# 399996          -0.4510  1 or 2
# 399997           0.6632  1 or 2
# 399998           0.9217  4 or 5
# 399999           0.9280  1 or 2
#
# [400000 rows x 4 columns]

# %% [markdown]
# ##1. Positive Feedback Rate

# %%
query = """
SELECT
1.0 * SUM(CASE WHEN sentiment_score > 0.05 THEN 1 ELSE 0 END) / COUNT(*) AS positive_feedback_rate
FROM sentiment;
"""
pd.read_sql_query(query, conn)
# Out:
#    positive_feedback_rate
# 0                  0.6988

# %% [markdown]
# ##2. Negative Feedback Rate

# %%
query = """
SELECT
1.0 * SUM(CASE WHEN sentiment_score < -0.05 THEN 1 ELSE 0 END) / COUNT(*) AS negative_feedback_rate
FROM sentiment;
"""
pd.read_sql_query(query, conn)
# Out:
#    negative_feedback_rate
# 0                0.276313

# %% [markdown]
# ##3. Average Sentiment Score

# %%
query = """
SELECT
AVG(sentiment_score) AS average_sentiment_score
FROM sentiment;
"""
pd.read_sql_query(query, conn)
# Out:
#    average_sentiment_score
# 0                 0.369767

# %% [markdown]
# ##4. Top Complaints

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from collections import Counter
query = "SELECT text FROM sentiment WHERE sentiment_score < -0.05"
df_negative = pd.read_sql_query(query, conn)

text_data = ' '.join(df_negative['text'].dropna())

tokens = re.findall(r'\b\w+\b', text_data.lower())
filtered_tokens = [word for word in tokens if word not in stop_words]

common_words = Counter(filtered_tokens).most_common(20)

print("Top Complaint Keywords in Negative Reviews:")
for word, count in common_words:
    print(f"{word}: {count}")
# Out:
# Top Complaint Keywords in Negative Reviews:
# book: 54504
# one: 41754
# would: 27952
# like: 25813
# movie: 22244
# time: 22096
# get: 22032
# good: 20484
# even: 19520
# bad: 18603
# read: 17963
# product: 17851
# buy: 16595
# really: 15693
# money: 15563
# first: 15127
# much: 13614
# work: 13320
# use: 12786
# could: 12778

# %% [markdown]
# ## SQL Implementation Plan

# %% [markdown]
# ###1. Table: reviews(id, product_id, text, sentiment_score, rating)

# %%
result = pd.read_sql_query("select * from sentiment", conn)
result
# Out:
#             id                                               text  \
# 0            1  Great CD: My lovely Pat has one of the GREAT v...
# 1            2  One of the best game music soundtracks - for a...
# 2            3  Batteries died within a year ...: I bought thi...
# 3            4  works fine, but Maha Energy is better: Check o...
# 4            5  Great for the non-audiophile: Reviewed quite a...
# ...        ...                                                ...
# 399995  399996  Unbelievable- In a Bad Way: We bought this Tho...
# 399996  399997  Almost Great, Until it Broke...: My son reciev...
# 399997  399998  Disappointed !!!: I bought this toy for my son...
# 399998  399999  Classic Jessica Mitford: This is a compilation...
# 399999  400000  Comedy Scene, and Not Heard: This DVD will be ...
#
#         sentiment_score  rating
# 0                0.9569  4 or 5
# 1                0.8770  4 or 5
# 2                0.7297  1 or 2
# 3                0.7845  4 or 5
# 4                0.8388  4 or 5
# ...                 ...     ...
# 399995           0.5932  1 or 2
# 399996          -0.4510  1 or 2
# 399997           0.6632  1 or 2
# 399998           0.9217  4 or 5
# 399999           0.9280  1 or 2
#
# [400000 rows x 4 columns]

# %% [markdown]
# ### 2. Calculate aggregates by sentiment group.

# %%
query = """
SELECT
  CASE
    WHEN sentiment_score > 0.05 THEN 'Positive'
    WHEN sentiment_score < -0.05 THEN 'Negative'
    ELSE 'Neutral'
  END AS sentiment_group,
  COUNT(*) AS total_reviews,
  AVG(sentiment_score) AS avg_sentiment_score
FROM sentiment
GROUP BY sentiment_group;
"""

df_summary = pd.read_sql_query(query, conn)
print(df_summary)
# Out:
#   sentiment_group  total_reviews  avg_sentiment_score
# 0        Negative         110525            -0.612562
# 1         Neutral           9955             0.000320
# 2        Positive         279520             0.771347

# %% [markdown]
# ##Python Implementation Plan

# %% [markdown]
# ### 1.	Use NLP tools to assign sentiment.

# %% [markdown]
# [Click me to view the following cell block](#scrollTo=3WObnYRUMXme&line=6&uniqifier=1)

# %% [markdown]
# ###2. Generate sentiment score distributions and review word clouds.

# %% [markdown]
# [Click me to view Sentiment Score Distribution](#scrollTo=3WObnYRUMXme&line=4&uniqifier=1)
#
#
# [Click me to view Word Clouds](#scrollTo=01MKm_0VjaIi&line=6&uniqifier=1)
